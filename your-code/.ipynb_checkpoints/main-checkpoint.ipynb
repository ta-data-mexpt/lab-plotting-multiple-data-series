# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('../data/liquor_store_sales.csv')
data.head()
data.dtypes
# Out:
# Year                 int64
# Month                int64
# Supplier            object
# ItemCode            object
# Description         object
# ItemType            object
# RetailSales        float64
# RetailTransfers    float64
# WarehouseSales     float64
# dtype: object

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
data_bar_chart= data[["RetailSales", "RetailTransfers","WarehouseSales","ItemType"]].groupby(["ItemType"]).agg("sum")
data_bar_chart.plot.bar();

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
data_bar_hor= data[["RetailSales","WarehouseSales","Supplier"]].groupby(["Supplier"]).agg("sum")
data_bar_hor["Tot"]=data_bar_hor["RetailSales"]+data_bar_hor["WarehouseSales"]
data_hor=data_bar_hor.sort_values(by="Tot",inplace=False,ascending=False).head(10)
data_hor.plot.barh();

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
data_bar_avg= data[["RetailSales", "RetailTransfers","WarehouseSales","Month","Year"]].groupby(["Year","Month"]).agg("mean").reset_index()
data_bar_avg["Date"]=data_bar_avg["Month"].astype("str")+"-"+"01"+"-"+data_bar_avg["Year"].astype("str")
data_bar_avg["Date"]=pd.to_datetime(data_bar_avg["Date"])
"01-"
data_bar_avg
data_bar_avg.plot(x="Date", y=["RetailSales","RetailTransfers","WarehouseSales"]);

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
data_bar_avg.plot.bar(x="Date", y=["RetailSales","RetailTransfers","WarehouseSales"]);

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
data["Date"]=data["Month"].astype("str")+"-"+"01"+"-"+data["Year"].astype("str")
data["Date"]=pd.to_datetime(data["Date"])
data_pivote=data.pivot_table(index="Date",columns="ItemType",values="RetailSales",fill_value=0,aggfunc="sum").reset_index()
data_pivote
# Out:
# ItemType       Date      BEER  DUNNAGE  KEGS    LIQUOR  NON-ALCOHOL    REF  \
# 0        2017-04-01      0.00        0     0      0.00         0.00   0.00
# 1        2017-05-01  25023.24        0     0  35123.36         0.00   0.00
# 2        2017-06-01  27863.26        0     0  35035.31      1209.23  30.60
# 3        2017-08-01  23030.13        0     0  32186.04      1091.28  19.54
# 4        2017-09-01  23852.76        0     0  32532.32       997.11  38.88
# 5        2017-10-01  22583.78        0     0  32491.59       945.63  22.82
# 6        2017-11-01  23341.14        0     0  35524.77      1005.19  63.11
# 7        2017-12-01  28822.16        0     0  49522.28      1316.44  41.21
# 8        2018-01-01  16606.33        0     0  28579.87       732.25  23.66
# 9        2018-02-01  18640.31        0     0  28852.31       812.84  41.52
#
# ItemType  STR_SUPPLIES      WINE
# 0                 0.00      0.00
# 1                 0.00  34546.89
# 2                89.22  33129.64
# ...

# %%
data_pivote.plot(x="Date", y=["BEER","DUNNAGE","KEGS","LIQUOR","NON-ALCOHOL","REF","STR_SUPPLIES","WINE"],figsize=(12,6));

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
data_pivote.plot.bar(x="Date", y=["BEER","DUNNAGE","KEGS","LIQUOR","NON-ALCOHOL","REF","STR_SUPPLIES","WINE"],figsize=(12,6));

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
#hue : es el color de la bolita 
# implot agrega las lineas de regresio y hace el histogram.

# %%
sns.lmplot(x="RetailSales", y="RetailTransfers",hue='ItemType', data= data);

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
# To mas columan numericas y verifica su relacion.

sns.pairplot(data,hue = 'ItemType')
