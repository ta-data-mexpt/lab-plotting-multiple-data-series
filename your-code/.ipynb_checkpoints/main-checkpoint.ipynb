# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('../data/liquor_store_sales.csv')
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128355 entries, 0 to 128354
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Year             128355 non-null  int64
#  1   Month            128355 non-null  int64
#  2   Supplier         128331 non-null  object
#  3   ItemCode         128355 non-null  object
#  4   Description      128355 non-null  object
#  5   ItemType         128354 non-null  object
#  6   RetailSales      128355 non-null  float64
#  7   RetailTransfers  128355 non-null  float64
#  8   WarehouseSales   128355 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 8.8+ MB

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
item_type = data[['ItemType','RetailSales','RetailTransfers','WarehouseSales']].groupby(['ItemType']).agg('sum')
item_type.plot.bar()
plt.title('Sales by Item Type')
plt.show()

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
top_10 = data.groupby(['Supplier']).agg({'RetailSales':'sum','RetailTransfers':'sum','WarehouseSales':'sum'})
top_10['Total Sales'] = top_10[['RetailSales','RetailTransfers','WarehouseSales']].astype('int32').sum(1)
top_10 = top_10.nlargest(10,'Total Sales')
top_10.plot.barh()
plt.title('Top 10 Suppliers with the most total sales')
plt.show()

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
avg_data = data.groupby(['Month']).agg({'RetailSales':'mean','RetailTransfers':'mean','WarehouseSales':'mean'}).reset_index()
avg_data.plot(x = 'Month', y =['RetailSales','RetailTransfers','WarehouseSales'])
plt.title('Average Sales per month over time')
plt.show()

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
avg_data.plot.bar()
plt.title('Average Sales per month over time')
plt.show()

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
retail_sales = data.groupby(['ItemType','Month','Year']).agg({'RetailSales':'sum','RetailTransfers':'sum'}).reset_index()
retail_sales
# Out:
#    ItemType  Month  Year  RetailSales  RetailTransfers
# 0      BEER      1  2018     16606.33         20661.55
# 1      BEER      2  2018     18640.31         17665.72
# 2      BEER      4  2017         0.00         20045.00
# 3      BEER      5  2017     25023.24         27133.83
# 4      BEER      6  2017     27863.26         28864.42
# ..      ...    ...   ...          ...              ...
# 68     WINE      8  2017     30707.45         30341.90
# 69     WINE      9  2017     32936.89         31545.10
# 70     WINE     10  2017     33108.76         34455.67
# 71     WINE     11  2017     38275.92         39335.40
# 72     WINE     12  2017     51492.76         48815.39
#
# [73 rows x 5 columns]

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
sns.scatterplot(data=data, x = 'RetailSales', y = 'RetailTransfers', hue = 'ItemType')
plt.title('Correlation between Retail Sales vs Retail Transfers')
plt.show()

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
# numeric_data = data.select_dtypes(exclude=object)
sns.pairplot(data, hue = 'ItemType')
plt.show()
