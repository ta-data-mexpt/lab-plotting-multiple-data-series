# %% [markdown]
# # Plotting Multiple Data Series
#
# Complete the following set of exercises to solidify your knowledge of plotting multiple data series with pandas, matplotlib, and seaborn. Part of the challenge that comes with plotting multiple data series is transforming the data into the form needed to visualize it like you want. For some of the exercises in this lab, you will need to transform the data into the form most appropriate for generating the visualization and then create the plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
data = pd.read_csv('../data/liquor_store_sales.csv')
data.head()
# Out:
#    Year  Month                      Supplier ItemCode  \
# 0  2017      4               ROYAL WINE CORP   100200
# 1  2017      4      SANTA MARGHERITA USA INC   100749
# 2  2017      4            JIM BEAM BRANDS CO    10103
# 3  2017      4  HEAVEN HILL DISTILLERIES INC    10120
# 4  2017      4               ROYAL WINE CORP   101664
#
#                              Description ItemType  RetailSales  \
# 0                      GAMLA CAB - 750ML     WINE          0.0
# 1   SANTA MARGHERITA P/GRIG ALTO - 375ML     WINE          0.0
# 2  KNOB CREEK BOURBON 9YR - 100P - 375ML   LIQUOR          0.0
# 3          J W DANT BOURBON 100P - 1.75L   LIQUOR          0.0
# 4            RAMON CORDOVA RIOJA - 750ML     WINE          0.0
#
#    RetailTransfers  WarehouseSales
# 0              1.0             0.0
# 1              1.0             0.0
# 2              8.0             0.0
# 3              2.0             0.0
# 4              4.0             0.0

# %% [markdown]
# ## 1. Create a bar chart with bars for total Retail Sales, Retail Transfers, and Warehouse Sales by Item Type.

# %%
sales_by_item = data[['RetailSales']].groupby(data.ItemType).sum().reset_index()
plt.bar(sales_by_item.ItemType, sales_by_item.RetailSales)
plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ## 2. Create a horizontal bar chart showing sales mix for the top 10 suppliers with the most total sales.

# %%
plt.subplots(1,1,figsize=(20,4))
suppliers = data[['RetailSales','WarehouseSales']].groupby(data.Supplier).sum().reset_index()
suppliers['TotalSales'] = suppliers.RetailSales + suppliers.WarehouseSales
suppliers.nlargest(10, 'TotalSales')
plt.bar(suppliers.nlargest(10, 'TotalSales').Supplier, suppliers.nlargest(10, 'TotalSales').TotalSales)
plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ## 3. Create a multi-line chart that shows average Retail Sales, Retail Transfers, and Warehouse Sales per month over time.

# %%
months = data[['RetailSales','RetailTransfers','WarehouseSales']].groupby(data.Month).mean().reset_index()
months.plot(x='Month')
#plt.xticks(list(range(12)),['','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec','Jan','Feb'])
plt.show()

# %% [markdown]
# ## 4. Plot the same information as above but as a bar chart.

# %%
fig, ax = plt.subplots()
ax.bar(months.Month-.2, months.RetailSales,width=0.2,color='b',label='RetailSales',align='center')
ax.bar(months.Month, months.RetailTransfers,width=0.2,color='g',label='RetailTransfers',align='center')
ax.bar(months.Month+.2, months.WarehouseSales,width=0.2,color='r',label='WarehouseSales',align='center')
plt.xticks(list(range(13)),['','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
plt.show()
#For some reason data for March and April is missing

# %% [markdown]
# ## 5. Create a multi-line chart that shows Retail Sales summed by Item Type over time (Year & Month).
#
# *Hint: There should be a line representing each Item Type.*

# %%
data['Day']='01'
data['date'] = pd.to_datetime(data[['Year', 'Month', 'Day']])
sales_by_item = data[['RetailSales']].groupby([data.ItemType,data.date]).sum().reset_index()
ax = sns.lineplot(x='date', y='RetailSales',data=data, hue='ItemType')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)
# Out:
# [Text(17257.0, 0, ''),
#  Text(17287.0, 0, ''),
#  Text(17318.0, 0, ''),
#  Text(17348.0, 0, ''),
#  Text(17379.0, 0, ''),
#  Text(17410.0, 0, ''),
#  Text(17440.0, 0, ''),
#  Text(17471.0, 0, ''),
#  Text(17501.0, 0, ''),
#  Text(17532.0, 0, ''),
#  Text(17563.0, 0, '')]

# %% [markdown]
# ## 6. Plot the same information as above but as a bar chart.

# %%
ax = sns.barplot(x='date', y='RetailSales',data=data, hue='ItemType')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)
# Out:
# [Text(0, 0, '2017-04-01T00:00:00.000000000'),
#  Text(1, 0, '2017-05-01T00:00:00.000000000'),
#  Text(2, 0, '2017-10-01T00:00:00.000000000'),
#  Text(3, 0, '2017-12-01T00:00:00.000000000'),
#  Text(4, 0, '2018-02-01T00:00:00.000000000'),
#  Text(5, 0, '2017-06-01T00:00:00.000000000'),
#  Text(6, 0, '2017-08-01T00:00:00.000000000'),
#  Text(7, 0, '2017-09-01T00:00:00.000000000'),
#  Text(8, 0, '2017-11-01T00:00:00.000000000'),
#  Text(9, 0, '2018-01-01T00:00:00.000000000')]

# %% [markdown]
# ## 7. Create a scatter plot showing the relationship between Retail Sales (x-axis) and Retail Transfers (y-axis) with the plot points color-coded according to their Item Type.
#
# *Hint: Seaborn's lmplot is the easiest way to generate the scatter plot.*

# %%
g = sns.lmplot(x="RetailSales", y="RetailTransfers", data=data, hue='ItemType')

# %% [markdown]
# ## 8. Create a scatter matrix using all the numeric fields in the data set with the plot points color-coded by Item Type.
#
# *Hint: Seaborn's pairplot may be your best option here.*

# %%
sns.pairplot(data, hue='ItemType')
